# %%
from bs4 import BeautifulSoup
import csv, requests
import pandas as pd
from tqdm import tqdm

# %%
pageList = ['AL','AK','AS','AZ','AR','CA','CO','CT','DE','DC','FM','FL','GA','GU','HI','ID','IL','IN','IA','KS','KY','LA','ME','MH','MD','MA','MI','MN','MS','MO','MT','NE','NV','NH','NJ','NM','NY','NC','ND','MP','OH','OK','OR','PW','PA','PR','RI','SC','SD','TN','TX','UT','VT','VI','VA','WA','WV','WI','WY']

# %%
for idx, page in tqdm(enumerate(pageList)):
    page = requests.get(F'https://www.hrsa.gov/coronavirus/health-center-program/participants/{page}')
    html = page.text
    soup = BeautifulSoup(html)
    table = soup.find('table')

    output_rows = []
    columnHeaders = ['Health Center Name', 'City', 'State', 'Status']
    for table_row in table.findAll('tr'):
        columns = table_row.findAll('td')
        if len(columns) == 0:
            continue
        output_row = {}
        for i in range(0, 4):
            output_row[columnHeaders[i]] = columns[i].text
        output_rows.append(output_row)
        
    if idx == 0:
        combinedDf = pd.DataFrame(output_rows)
    else:
        combinedDf = pd.concat([combinedDf, pd.DataFrame(output_rows)])
# Out:
# 59it [00:22,  2.63it/s]

# %%
combinedDf.to_csv('CLINICS_3_11.csv',index=False)

# %%
clinics_list = pd.read_csv('C:/Users/halpe/Documents/GitHub/covid-production/public/csv/context_fqhc_clinics_hrsa.csv')

# %%
clinics_list['name'] = clinics_list['name'].str.upper()

# %%
combinedDf['Health Center Name'] = combinedDf['Health Center Name'].str.upper()

# %%
clinics_list
# Out:
#                                      name st_abbr       city  \
# 0         SOUTHERN REGION COMM HEALTH CTR      GU   Inarajan
# 1           NORTHERN REGION COMM HLTH CTR      GU     Dededo
# 2            TINIAN ISLA COMMUNITY HEALTH      MP     Tinian
# 3                  KCHC - KAMAN II CLINIC      MP     Saipan
# 4             OFU COMMUNITY HEALTH CENTER      AS  Pago Pago
# ...                                   ...     ...        ...
# 13572  P.S. 28 SCHOOL-BASED HEALTH CENTER      NY   New York
# 13573                        PS 46 TAPPAN      NY   New York
# 13574      COMMUNITY LEAGUE HEALTH CENTER      NY   New York
# 13575               PHOENIX HEALTH CENTER      NY   New York
# 13576                              CES 73      NY      Bronx
#
#                                         address         phone testing_status  \
# 0                                  162 Apman Dr  671-828-7501            Yes
# ...
